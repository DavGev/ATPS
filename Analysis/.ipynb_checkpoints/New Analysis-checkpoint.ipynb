# %%
# %run Data.ipynb

# %%
# %run Functions.ipynb

# %%
import cProfile
import pstats

with cProfile.Profile() as pr:
    res = least_squares(fun_I, np.ones(3), args=(PEG[:, 0:10], n_PEG), bounds=(0, np.inf))
    
stats = pstats.Stats(pr)
stats.sort_stats(pstats.SortKey.TIME)
stats.print_stats()
#stats.dump_stats(filename='needs_profiling.prof')
# Out:
# C:\Users\Davit\AppData\Local\Temp/ipykernel_2956/1357775187.py:32: RuntimeWarning: invalid value encountered in power
#   c01_model = k * np.power(c0, a0) * np.power(c1, a1)
#          395349 function calls (393527 primitive calls) in 1.788 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     38758    0.893    0.000    0.893    0.000 C:\Users\Davit\AppData\Local\Temp/ipykernel_2956/1357775187.py:26(Fun_For_Concentrations)
#      3957    0.181    0.000    0.271    0.000 C:\Users\Davit\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\linalg\linalg.py:2157(lstsq)
#      4710    0.091    0.000    0.844    0.000 {built-in method scipy.optimize._minpack._hybrd}
#       314    0.082    0.000    0.396    0.001 C:\Users\Davit\AppData\Local\Temp/ipykernel_2956/3391606609.py:1(f0_f1_f01)
# ...

# %%
import cProfile
import pstats

with cProfile.Profile() as pr:
    x0 = .5*np.ones(6)
    res = least_squares(fun_mI, x0, args=(PEG[:, 0:10], n_PEG),
                        bounds=(0, [np.inf, np.inf, np.inf, 1, 1, 1]))
    
stats = pstats.Stats(pr)
stats.sort_stats(pstats.SortKey.TIME)
stats.print_stats()
#stats.dump_stats(filename='needs_profiling.prof')
# Out:
# C:\Users\Davit\AppData\Local\Temp/ipykernel_2956/1357775187.py:32: RuntimeWarning: invalid value encountered in power
#   c01_model = k * np.power(c0, a0) * np.power(c1, a1)
# C:\Users\Davit\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
#          439426 function calls (438030 primitive calls) in 4.356 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    135698    3.273    0.000    3.273    0.000 C:\Users\Davit\AppData\Local\Temp/ipykernel_2956/1357775187.py:26(Fun_For_Concentrations)
#      7575    0.323    0.000    3.285    0.000 {built-in method scipy.optimize._minpack._hybrd}
# ...

# %% [markdown]
# # Two-Component Solutions
#
# ### Model
# We assume that there are complexes of solvent and solute.
#
# $f = c_0 f_0 + c_1 f_1 + c_{01} f_{01}$
#
# $c_{01} = k {c_0^{\alpha_0} c_1^{\alpha_1}}$
#
# $n_0 = c_0 + \alpha_0 c_{01}$
#
# $n_1 = c_1 + \alpha_1 c_{01}$

# %% [markdown]
# ### Variabels
#
# $f$ is the absorbence fo the solution,
#
# $f_0$, $f_1$ and $f_{01}$ are there absorbencees of the components (solvent, solute and complex),
#
# $c_0$, $c_1$ and $c_{01}$ are the concentrations,
#
# $k$ is the raction coefficient
#
# $\alpha_0$ and $\alpha_1$ are the numbers of atoms in the complex
#
# $n_0$ and $n_1$ are the initia concentrations

# %% [markdown]
# # Phase I

# %%
Results_PEG_I = Estimate_I(PEG, n_PEG)
# Out:
#   0%|          | 0/892 [00:00<?, ?it/s]
# C:\Users\Davit\AppData\Local\Temp/ipykernel_2956/1357775187.py:32: RuntimeWarning: invalid value encountered in power
#   c01_model = k * np.power(c0, a0) * np.power(c1, a1)

# %%
Redused_Lambda = Lambda[50:-49:5]
#Redused_Lambda = Lambda[50:-49]

# %%
k_I, a0_I, a1_I = get_k_a0_a1_I(Results_PEG_I)
c0_I, c1_I, c01_I = Concentrations(k_I, a0_I, a1_I, n_PEG)
f0_I, f1_I, f01_I = f0_f1_f01(c0_I, c1_I, c01_I, PEG[:, 50:-49])
PEG_pred = Predict_fast(c0_I, c1_I, c01_I, f0_I, f1_I, f01_I)

#np.savetxt('../Results/k_I.txt',k_I)
#np.savetxt('../Results/a0_I.txt',a0_I)
#np.savetxt('../Results/a1_I.txt',a1_I)

# %%
i = 13

plt_spectrum_header()

plt.plot(Redused_Lambda, PEG_pred[i], label='Predicted')
plt.plot(Redused_Lambda, PEG[i,50:-49:5], label='Experiment')

plt.legend()

# %% [markdown]
# # Old

# %%
plt_spectrum_header()

plt.plot(Redused_Lambda, a0_I/10, '.', label='water number I')
plt.plot(Redused_Lambda, NaPB[50:-49], label='water')

plt.legend()

# %%
plt_spectrum_header()

plt.plot(Redused_Lambda, a1_I/10, '.', label='PEG number_I')
plt.plot(Redused_Lambda, PEG_Pure[50:-49], label='PEG')

plt.legend()

# %%
plt_spectrum_header()

plt.plot(Redused_Lambda, f01_I, label='f01_I')
plt.plot(Redused_Lambda, NaPB[50:-49], label='water')
plt.plot(Redused_Lambda, PEG_Pure[50:-49], label='PEG')

plt.legend()

# %%
plt_spectrum_header()

for n, f, f_pred in zip(n_PEG, PEG, PEG_pred):
    plt.plot(Redused_Lambda, f[50:-49], label='exp, '+str(int(n*100))+'%')
    plt.plot(Redused_Lambda, f_pred, label='pred, '+str(int(n*100))+'%')
plt.legend()

# %% [markdown]
# # Phase II

# %%
History_PEG_II = []

# %%
Results_PEG_II = Estimate_Liquid_k_a0_a1_II(a0_I, a1_I, n_PEG, NaPB, PEG_Pure, PEG, History_PEG_II, batch=100)
# Out:
#   0%|          | 0/4366 [00:00<?, ?it/s]

# %%
k_II, a0_II, a1_II = get_k_a0_a1_II(Results_PEG_II)

np.savetxt('../Results/k_II.txt',k_II)
np.savetxt('../Results/a0_II.txt',a0_II)
np.savetxt('../Results/a1_II.txt',a1_II)

# %%
c0_II, c1_II, c01_II = Concentrations(k_II, a0_II, a1_II, n_PEG)

# %%
f01_II = Liquid_f01(c0_II, c1_II, c01_II, NaPB[50:-49], PEG_Pure[50:-49], PEG[:, 50:-49])

# %%
Redused_Lambda = Lambda[50:-49]

plt_spectrum_header()

plt.plot(Redused_Lambda, a0_I/100, '.', label='water number I')
plt.plot(Redused_Lambda, a0_II/100, '.', label='water number II')
plt.plot(Redused_Lambda, NaPB[50:-49], label='water')


plt.legend()

# %%
plt_spectrum_header()

plt.plot(Redused_Lambda, a1_I/100, '.', label='PEG number_I')
plt.plot(Redused_Lambda, a1_II/100, '.', label='PEG number_II')
plt.plot(Redused_Lambda, PEG_Pure[50:-49], label='PEG')

plt.legend()

# %%
plt_spectrum_header()

plt.plot(Redused_Lambda, f01_I, label='f01_I')
plt.plot(Redused_Lambda, f01_II, label='f01_II')
plt.plot(Redused_Lambda, NaPB[50:-49], label='water')
plt.plot(Redused_Lambda, PEG_Pure[50:-49], label='PEG')

plt.legend()

# %%
PEG_pred = Predict(k_II, a0_II, a1_II, n_PEG, NaPB[50:-49], PEG_Pure[50:-49], f01_II)

# %%
i = 7

plt_spectrum_header()

plt.plot(Redused_Lambda, PEG_pred[i], label='Predicted')
plt.plot(Redused_Lambda, PEG[i,50:-49], label='Experiment')

plt.legend()

# %% [markdown]
# BSA protein, фикол, декстран
